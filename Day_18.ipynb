# %% [markdown]
# <a href="https://colab.research.google.com/github/srishanth18varma/python_course_work/blob/main/Day_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Recursion

# %%
def factorial(n):
  if n == 1:
    return 1
  return (n * factorial(n - 1))

print(factorial(5))
# Out:
# 120
